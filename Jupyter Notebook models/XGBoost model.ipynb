# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
#cars = pd.read_csv('used_Updated.csv')

# %%
cars.describe()
# Out:
#                Cena       Godiste    Kilometraza      Kubikaza         Snaga
# count  37518.000000  37518.000000   37518.000000  37518.000000  37518.000000
# mean    4231.637347   2005.863159  207763.071646   1763.229810    114.134975
# std     3487.205585      4.698312   53561.556641    312.761337     32.554313
# min      500.000000   1982.000000   41000.000000    900.000000     50.000000
# 25%     1927.250000   2003.000000  175000.000000   1560.000000     90.000000
# 50%     3000.000000   2005.000000  203223.000000   1896.000000    110.000000
# 75%     5300.000000   2009.000000  241157.500000   1992.000000    136.000000
# max    22000.000000   2020.000000  350000.000000   3000.000000    298.000000

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Brend', data=cars, order=cars['Brend'].value_counts().index)

# %%
plt.figure(figsize=(20,5))
sns.countplot(x='Model', data=cars[cars['Brend']=='VOLKSWAGEN'], order=cars[cars['Brend']=='VOLKSWAGEN']['Model'].value_counts().index)

# %%
sns.scatterplot(x='Kilometraza',y='Cena', data=cars[cars['Model']=='PASSAT B6'])

# %%
data=cars[cars['Model']=='PASSAT B6']
sns.boxplot(x='Model',y='Cena', data=data)

# %%
cars.drop(cars[(cars['Model']=='PASSAT B6') & (cars['Cena']>6700)].index, inplace=True)
cars.drop(cars[(cars['Model']=='PASSAT B6') & (cars['Cena']<2800)].index,inplace=True)

# %%
data=cars[cars['Model']=='PASSAT B6']
sns.boxplot(x='Model',y='Kilometraza', data=data)

# %%
cars.drop(cars[(cars['Model']=='PASSAT B6') & (cars['Kilometraza']>330000)].index, inplace=True)
cars.drop(cars[(cars['Model']=='PASSAT B6') & (cars['Kilometraza']<140000)].index,inplace=True)

# %%
cars.drop(cars[(cars['Model']=='PASSAT B6') & (cars['Snaga']>190)].index, inplace=True)

# %%
sns.boxplot(x='Model',y='Snaga', data=data)

# %%
cars.drop(cars[(cars['Model']=='PASSAT B6') & (cars['Kubikaza']>2100)].index, inplace=True)
cars.drop(cars[(cars['Model']=='PASSAT B6') & (cars['Kubikaza']<1800)].index,inplace=True)

# %%
sns.boxplot(x='Model',y='Kubikaza', data=cars[(cars['Model']=='PASSAT B6')])

# %%
sns.boxplot(x='Model',y='Godiste', data=cars[(cars['Model']=='PASSAT B6')])

# %%
cars.drop(cars[(cars['Model']=='PASSAT B6') & (cars['Godiste']>2008)].index, inplace=True)

# %%
sns.countplot(x='Karoserija', data=data)

# %%
sns.countplot(x='Gorivo', data=data)

# %%
sns.scatterplot(x='Godiste',y='Cena', data=cars[cars['Model']=='PASSAT B6'], hue='Karoserija')

# %%
import numpy as np
plt.figure(figsize=(7,15))
sns.scatterplot(x='Godiste',y='Cena', data=cars, hue='Kilometraza')
plt.yticks(np.arange(cars['Cena'].min(), cars['Cena'].max(), 1000))
# Out:
# ([<matplotlib.axis.YTick at 0x1de891d0308>,
# ...
#  <a list of 22 Text yticklabel objects>)

# %%
cars.drop(cars[(cars['Godiste']<=2005) &  (cars['Cena']>=8600)].index, inplace=True)
cars.drop(cars[(cars['Godiste']<=2000) &  (cars['Cena']>=3700)].index, inplace=True)

# %%
cars['Godiste'].min()
# Out:
# 1982

# %%
sns.distplot(cars['Godiste'])

# %%
cars.drop(cars[(cars['Godiste']<1990)].index, inplace=True)

# %%
cars.drop(cars[(cars['Godiste']<=2000) &  (cars['Cena']>=4800)].index, inplace=True)

# %%
sns.scatterplot(x='Kilometraza',y='Cena', data=cars[cars['Model']=='PASSAT B6'], hue='Kubikaza')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# creating instance of labelencoder
labelencoder = LabelEncoder()
# Encoding text variables into numerical
cars['Gorivo'] = labelencoder.fit_transform(cars['Gorivo'])
cars['Karoserija']  = labelencoder.fit_transform(cars['Karoserija'])

# %%
import xgboost
from xgboost import XGBRegressor
from xgboost import plot_importance
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
import pickle
brands = cars.groupby('Brend')


row_list=[]
for b, items in brands:
    print("Brand: {}".format(b))
    model = items.groupby('Model')
    for m, items in  model:
        print("Model: {}".format(m))
        model_m = cars[cars['Model']==m]
        X = model_m[['Godiste', 'Gorivo', 'Karoserija', 'Kilometraza', 'Kubikaza', 'Snaga']]
        y = model_m[['Cena']]
        
        #scaler = MinMaxScaler()
       
        
        # Split the data into train/test data
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
        boost = XGBRegressor(colsample_bytree=0.7, learning_rate=0.03, max_depth= 5, min_child_weight= 4, n_estimators= 500, nthread=4, objective='reg:squarederror', silent= 1, subsample= 0.7)
        X_train = X_train.values
        X_test = X_test.values
         ### Tuning hyper-parameters
        """parameters = {'nthread':[4], #when use hyperthread, xgboost may become slower
              'objective':['reg:squarederror'],
              'learning_rate': [.03, 0.05, .07], #so called `eta` value
              'max_depth': [5, 6, 7],
              'min_child_weight': [4],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500]}

        xgb_grid = GridSearchCV(boost,
                        parameters,
                        cv = 2,
                        n_jobs = 5,
                        verbose=True)
        print(xgb_grid.best_score_)
        print(xgb_grid.best_params_)
                        """
        
        
        boost.fit(X_train, y_train) # .values.ravel()
        
        
        
        
       
        
        # Predictions
        predictions = boost.predict(X_test)
        mae = metrics.mean_absolute_error(y_test, predictions)
        rmse = np.sqrt(metrics.mean_squared_error(y_test,predictions))
        r2 = metrics.r2_score(y_test,predictions)
        print("Mae is: {}".format(mae))
        print("RMSE is: {}".format(rmse))
        print("R2 score is: {}".format(r2))
        
        
        # Save ML model
        directory = 'C:\\Users\\HP\\Documents\\Diplomski\\XG_Models\\'
        file_name = directory + '' + b+'_'+m+'_XG'+'.pkl'
        with open(file_name, 'wb') as file:  
            pickle.dump(boost, file)
        
        # Append errors to new dataframe for further analysis
        dict_ = {'Brand':b,'Model':m,'MAE':metrics.mean_absolute_error(y_test, predictions),'R2':r2,'RMSE':np.sqrt(metrics.mean_squared_error(y_test, predictions))}
        row_list.append(dict_)
        

        fig, ax = plt.subplots()
        ax.scatter(y_test, predictions, edgecolors=(0, 0, 1))
        #ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
        ax.set_xlabel('Stvarne vrednosti')
        ax.set_ylabel('Predviđene')
        ax.set_title("Brend: {} Model: {}".format(b,m))
        plt.show()
        
        
        
            

errors = pd.DataFrame(row_list)
# Out:
# Brand: ALFA ROMEO
# Model: 147
# [22:20:27] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Mae is: 338.16555188365817
# RMSE is: 458.7701408552274
# R2 score is: 0.4272514745452213
# Model: 156
# [22:20:28] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Mae is: 382.8785860501803
# RMSE is: 493.3598625252241
# ...

# %%
errors
# Out:
#           Brand    Model          MAE        R2         RMSE
# 0    ALFA ROMEO      147   307.159280  0.612323   387.937280
# 1    ALFA ROMEO      156   414.140520  0.077644   575.938022
# 2    ALFA ROMEO      159   661.052702  0.438142   905.867728
# 3          AUDI       A3   528.508146  0.823370   652.387907
# 4          AUDI       A4   574.979174  0.907348   786.788577
# ..          ...      ...          ...       ...          ...
# 97   VOLKSWAGEN     POLO   333.363924  0.891250   452.531438
# 98   VOLKSWAGEN   SHARAN   940.851703  0.867158  1535.202992
# 99   VOLKSWAGEN   TIGUAN  1333.436420  0.771794  1599.073844
# 100  VOLKSWAGEN  TOUAREG  1316.377950  0.847464  1496.612994
# 101  VOLKSWAGEN   TOURAN   507.785192  0.923179   753.852612
#
# [102 rows x 5 columns]

# %%
errors['MAE'].mean()
# Out:
# 639.7890169103465

# %%
plt.figure()
sns.distplot(errors['R2'],bins=20, kde=False)

# %%
errors['R2'].mean()
# Out:
# 0.628113950237666

# %%
with open('XG_Models\AUDI_A3_XG.pkl', 'rb') as file:  
    audiA3 = pickle.load(file)

# %%
fv= [2010,2,1,150000,1600,145]
fv = np.array(fv).reshape((1,-1))
#fv = xgboost.DMatrix(fv)
audiA3.predict(fv)
# Out:
# array([7130.3076], dtype=float32)
